# %%
# Primeiro notebook, apenas para "aquecer".
nome = 'Francisco'
idade = 43
print(f'Nome: {nome}, Idade: {idade} ')
# Out:
# Nome: Francisco, Idade: 43

# %%
print('\'s, \"x\", \\\\')
# Out:
# 's, "x", \\

# %%
pi = 3.1415926
print(f'Pi = {pi:.2f}')
# Out:
# Pi = 3.14

# %%
print((5*7)-((6*4)+(20/2)))
# Out:
# 1.0
