# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
sns.set_style('whitegrid')

# %%
dados = pd.read_csv('compras.csv')

# %%
dados.head()
# Out:
#    Tempo de Conexao  Idade     Renda  Media Diaria de Internet  \
# 0             68.95     35  61833.90                    256.09
# 1             80.23     31  68441.85                    193.77
# 2             69.47     26  59785.94                    236.50
# 3             74.15     29  54806.18                    245.89
# 4             68.37     35  73889.99                    225.58
#
#                                Cabecalho          Cidade  Sexo        Pais  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#         Horario Clique  Comprou
# 0  2016-03-27 00:53:11        0
# 1  2016-04-04 01:39:02        0
# 2  2016-03-13 20:35:42        0
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
# Tempo de Conexao            1000 non-null float64
# Idade                       1000 non-null int64
# Renda                       1000 non-null float64
# Media Diaria de Internet    1000 non-null float64
# Cabecalho                   1000 non-null object
# Cidade                      1000 non-null object
# Sexo                        1000 non-null int64
# Pais                        1000 non-null object
# Horario Clique              1000 non-null object
# Comprou                     1000 non-null int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
dados.shape
# Out:
# (1000, 10)

# %%
dados.describe()
# Out:
#        Tempo de Conexao        Idade         Renda  Media Diaria de Internet  \
# count       1000.000000  1000.000000   1000.000000               1000.000000
# mean          65.000200    36.009000  55000.000080                180.000100
# std           15.853615     8.785562  13414.634022                 43.902339
# min           32.600000    19.000000  13996.500000                104.780000
# 25%           51.360000    29.000000  47031.802500                138.830000
# 50%           68.215000    35.000000  57012.300000                183.130000
# 75%           78.547500    42.000000  65470.635000                218.792500
# max           91.430000    61.000000  79484.800000                269.960000
#
#               Sexo     Comprou
# count  1000.000000  1000.00000
# mean      0.481000     0.50000
# std       0.499889     0.50025
# min       0.000000     0.00000
# 25%       0.000000     0.00000
# 50%       0.000000     0.50000
# 75%       1.000000     1.00000
# ...

# %%
plt.figure(figsize=(10,8))
dados.Idade.hist(bins=dados.Idade.nunique())
plt.xlabel('Idade')
# Out:
# Text(0.5, 0, 'Idade')

# %%
sns.jointplot(dados['Renda'], dados.Idade)

# %%
sns.pairplot(dados, hue='Comprou')
# Out:
# /home/francisco/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/francisco/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
plt.plot(dados['Renda'], dados.Idade)

# %%
sns.jointplot(data = dados, x = 'Renda', y = 'Idade')

# %%
sns.jointplot(data = dados, y = 'Renda', x = 'Idade')

# %%
plt.scatter(dados.Renda, dados.Idade, s=1)

# %%
plt.scatter(dados.Renda, dados.Idade, s=10)

# %%
plt.scatter(dados.Renda, dados.Idade, s=50)

# %%
plt.scatter(x = dados.Idade, y=dados.Renda, s=3*np.pi)

# %%
plt.scatter(x = dados.Idade, y=dados.Renda)

# %%
filmes = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]

# %%
num_oscars = [5, 11, 3, 8, 10]

# %%
xs = [i for i, _ in enumerate(filmes)]

# %%
plt.bar(xs, num_oscars)
# Out:
# <BarContainer object of 5 artists>

# %%
xs = [i + 0.1 for i, _ in enumerate(filmes)]

# %%
plt.bar(xs, num_oscars)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.ylabel("# de Premiações")
plt.title("Meus Filmes Favoritos")
# Out:
# Text(0.5, 1.0, 'Meus Filmes Favoritos')

# %%
plt.xticks([i for i, _ in enumerate(filmes)], filmes)
plt.show()

# %%
plt.xticks([i+0.5 for i, _ in enumerate(filmes)], filmes)
plt.show()
