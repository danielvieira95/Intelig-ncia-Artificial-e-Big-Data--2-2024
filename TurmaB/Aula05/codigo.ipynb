# %%
# Exemplo 1
import numpy as np # importa a biblioteca numpy
from sklearn.linear_model import LinearRegression # da biblioteca
import matplotlib.pyplot as plt
# sklearn importa o modelo de regressao linear

# %%
# pip install scikit-learn instala a biblioteca scikit

# %%
# Dados de treinamento
vazao = np.array([10, 20, 30, 5, 35, 40]).reshape(-1, 1)  
# vazão de água em m3/min
nivel = np.array([50, 60, 70, 45, 80, 85])  # nível do tanque 
#em metros
# Criar e treinar o modelo de regressão linear
modelo = LinearRegression() # cria uma variavel chamada modelo
modelo.fit(vazao, nivel) # cria o modelo com base nos dados de entrada
# Out:
# LinearRegression()

# %%
# Dados de teste
#vazao_teste = np.array([15, 25, 33]).reshape(-1, 1)  # vazão de água em m3/min
vazao_teste = np.array([5, 2, 7,30,50]).reshape(-1, 1)  # vazão de água em m3/min
# Fazer previsões com base na vazão de água
nivel_previsto = modelo.predict(vazao_teste)

# %%
# Imprimir as previsões
for i in range(len(vazao_teste)): # laço de repetição para exibir os dados
    # de saida
    print(f"Vazão: {vazao_teste[i][0]} m3/min - Nível previsto: {nivel_previsto[i]} metros")
# gráfico de pontos - scatter
plt.scatter(vazao, nivel, color='blue', label='Dados de Treinamento') 
# gráfico de linhas 
plt.plot(vazao_teste,nivel_previsto, color  = 'red',label='Dados de teste')
plt.xlabel('Vazão de Água (m3/min)')
plt.ylabel('Nível do Tanque (metros)')
plt.title('Relação entre Vazão de Água e Nível do Tanque')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Vazão: 5 m3/min - Nível previsto: 44.02542372881356 metros
# Vazão: 2 m3/min - Nível previsto: 40.59322033898305 metros
# Vazão: 7 m3/min - Nível previsto: 46.313559322033896 metros
# Vazão: 30 m3/min - Nível previsto: 72.62711864406779 metros
# Vazão: 50 m3/min - Nível previsto: 95.50847457627117 metros

# %%
# Dados de teste
#vazao_teste = np.array([15, 25, 33]).reshape(-1, 1)  # vazão de água em m3/min
vazao_teste = np.array([100, 200, 70,300,500]).reshape(-1, 1)  # vazão de água em m3/min
# Fazer previsões com base na vazão de água
nivel_previsto = modelo.predict(vazao_teste)

# %%
# Imprimir as previsões
for i in range(len(vazao_teste)): # laço de repetição para exibir os dados
    # de saida
    print(f"Vazão: {vazao_teste[i][0]} m3/min - Nível previsto: {nivel_previsto[i]} metros")
# gráfico de pontos - scatter
plt.scatter(vazao, nivel, color='blue', label='Dados de Treinamento') 
# gráfico de linhas 
plt.plot(vazao_teste,nivel_previsto, color  = 'red',label='Dados de teste')
plt.xlabel('Vazão de Água (m3/min)')
plt.ylabel('Nível do Tanque (metros)')
plt.title('Relação entre Vazão de Água e Nível do Tanque')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Vazão: 100 m3/min - Nível previsto: 152.71186440677963 metros
# Vazão: 200 m3/min - Nível previsto: 267.1186440677966 metros
# Vazão: 70 m3/min - Nível previsto: 118.38983050847456 metros
# Vazão: 300 m3/min - Nível previsto: 381.5254237288135 metros
# Vazão: 500 m3/min - Nível previsto: 610.3389830508474 metros

# %%
# Dados de treinamento
q = np.array([0,100, 200, 300, 400,500, 600,700]).reshape(-1, 1)  
# vazão de água em m3/min
temp = np.array([0,30, 35, 40, 45, 60, 100,150]).reshape(-1,1)  # nível do tanque 
#em metros
# Criar e treinar o modelo de regressão linear
modelo = LinearRegression() # cria uma variavel chamada modelo
modelo.fit(q, temp) # cria o modelo com base nos dados de entrada
# Out:
# LinearRegression()

# %%
# Dados de teste
#vazao_teste = np.array([15, 25, 33]).reshape(-1, 1)  # vazão de água em m3/min
#q_teste = np.array([0,10, 20, 30,40,50,60,70]).reshape(-1, 1)  # vazão de água em m3/min
q_teste = np.array([90,190, 307, 440,510,602,690]).reshape(-1, 1)
# Fazer previsões com base na vazão de água
t_previsto = modelo.predict(q_teste)

# %%
# Imprimir as previsões
for i in range(len(q_teste)): # laço de repetição para exibir os dados
    # de saida
    print(f"Calor: {q_teste[i][0]} cal/min - Temp prevista: {t_previsto[i]} ºC")
# gráfico de pontos - scatter
plt.scatter(q, temp, color='blue', label='Dados de Treinamento') 
# gráfico de linhas 
plt.plot(q_teste,t_previsto, color  = 'red',label='Dados de teste')
plt.xlabel('Q (cal/min)')
plt.ylabel('Temperatura (ºC)')
plt.title('Relação entre Calorias temperatura')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Calor: 90 cal/min - Temp prevista: [11.69047619] ºC
# Calor: 190 cal/min - Temp prevista: [29.30952381] ºC
# Calor: 307 cal/min - Temp prevista: [49.92380952] ºC
# Calor: 440 cal/min - Temp prevista: [73.35714286] ºC
# Calor: 510 cal/min - Temp prevista: [85.69047619] ºC
# Calor: 602 cal/min - Temp prevista: [101.9] ºC
# Calor: 690 cal/min - Temp prevista: [117.4047619] ºC

# %%
a= 5.3
print(f"{a:.2f}")
# Out:
# 5.30
