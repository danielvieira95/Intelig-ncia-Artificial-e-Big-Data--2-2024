# %%
import pandas as pd # importa a biblioteca pandas
import matplotlib.pyplot as plt # importa a biblioteca matplotlib
import numpy as np # importa a biblioteca numpy

# %%
# Gerando numeros com a numpy
dados_x = np.linspace(0,10,10) #gera valores com a biblioteca numpy
dados_y = dados_x * dados_x #gera valores multiplicando um dado pelo outro

# %%
plt.figure(figsize =(10,5),facecolor='gray')
Ax = plt.axes() # cria os eixos do grafico
Ax.set_facecolor('white') # cria o fundo do grafico
plt.plot(dados_x,dados_y,
         color='red',linewidth=2,
        marker= 'o',linestyle = 'dashed',markeredgecolor='black')
plt.xlabel("Eixo x",fontsize=12) # adiciona titulo do eixo x
plt.ylabel("Eixo y",fontsize=12) # adiciona titulo do eixo y
plt.title("Exemplo Matplotlib",fontsize=12) # adiciona titulo do grafico
# Out:
# Text(0.5, 1.0, 'Exemplo Matplotlib')

# %%
plt.rcParams.update({'font.size':15}) # define o tamanho da fonte
plt.figure(figsize=(12,12)) # define o tamanho da figura
linhas=2 #define o numero de linhas
colunas=2 # define o numero de colunas
plt.subplot(linhas,colunas,1) # define o numero de linhas e colunas para plotar os graficos
plt.plot(dados_x,'r--')
plt.title("Grafico 1")
 #grafico 2
plt.subplot(linhas,colunas,2)
plt.plot(dados_x*dados_x,'b-.')
plt.title("Grafico 2")
#grafico 3
plt.subplot(linhas,colunas,3)
plt.plot(dados_x/2,'c-.')
plt.title("Grafico 3")
#grafico 4
plt.subplot(linhas,colunas,4)
plt.plot(dados_y*2,'r--')
plt.title("Gráfico 4")
plt.savefig("Exemplo subplot.jpg",dpi=300,transparent=True,
             bbox_inches= 'tight') # comando para salvar a figura

# %%
#Grafico de barras
Figura = plt.figure() # Armazena na variavel Figura a a figura a ser gerada
Grafico = Figura.add_axes([0,0,0.7,0.7]) # cria a grade do gráfico
Rotulos =['A','B','C','D','E','F','G','H','I','J'] # cria os rotulos 
Grafico.bar(Rotulos,dados_x)
plt.title("Quantidade x categoria")
plt.xlabel("Itens")
plt.ylabel("Quantidade")
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
#Grafico de barras
Figura = plt.figure() # Armazena na variavel Figura a a figura a ser gerada
Grafico = Figura.add_axes([0,0,0.7,0.7]) # cria a grade do gráfico
Rotulos =['A','B','C','D','E','F','G','H','I','J'] # cria os rotulos 
Grafico.bar(Rotulos,dados_x,color='blue')
Grafico.bar(Rotulos,dados_x*0.1,color='red')
plt.title("Quantidade x categoria")
plt.xlabel("Itens")
plt.ylabel("Quantidade")
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
#Grafico de barras
Figura = plt.figure() # Armazena na variavel Figura a a figura a ser gerada
Grafico = Figura.add_axes([0,0,0.7,0.7]) # cria a grade do gráfico
Rotulos =['A','B','C','D','E','F','G','H','I','J'] # cria os rotulos 
Grafico.bar(Rotulos,dados_x,dados_x*0.1,color=['blue','red'])

plt.title("Quantidade x categoria")
plt.xlabel("Itens")
plt.ylabel("Quantidade")
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
plt.boxplot(dados_x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x299d5feda10>,
#   <matplotlib.lines.Line2D at 0x299d5704210>],
#  'caps': [<matplotlib.lines.Line2D at 0x299d5704610>,
#   <matplotlib.lines.Line2D at 0x299d5707110>],
#  'boxes': [<matplotlib.lines.Line2D at 0x299d5727850>],
#  'medians': [<matplotlib.lines.Line2D at 0x299d57063d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x299d16ff250>],
#  'means': []}
